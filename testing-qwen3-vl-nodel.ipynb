# %% [markdown]
# <a href="https://colab.research.google.com/github/aurotripathy/1st-voice-app/blob/main/testing-qwen3-vl-nodel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# this ithe rough architecture

from IPython.display import Image, display

# Specify the path to your image file
image_path = '/content/arch.jpg'

# Display the image
display(Image(filename=image_path))
